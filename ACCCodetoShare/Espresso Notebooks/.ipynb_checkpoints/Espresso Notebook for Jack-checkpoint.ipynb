# %% [markdown]
# ## Import Libraries and set up input and output paths

# %%
# First import all necessary libraries to run the script
import sys
sys.path.append("..") # so we can import espresso from the directory above.
import os
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import dabest 
import espresso as esp
print('Espresso Version' + esp.__version__)


# Tell it where the files are, we are expecting at least one FeedLog and one Metadata file
mainDataPath='/Users/xusy/Data/Espresso/Jack/2019-12-13_R58E02Gal4-UAS-ACR1-starved-24hr-25deg-LightOn1Flies'

# Make a folder for the pictures you are about to dump, if, after checking, there is no existing "images" folder
imagepath=mainDataPath+'/' 'images/'
mainDataPathList=os.listdir(mainDataPath)
if [s for s in mainDataPathList if 'images' in s]==[]:
    os.mkdir(imagepath)
dataFolders = [s for s in mainDataPathList if "20" in s]
# Out:
# Espresso Version0.7.3

# %%
# Read all the data from the folder with espresso analysis code "espresso" and store as a dataframe called "all_Data"
all_Data=esp.espresso(mainDataPath, expt_duration_minutes=120)
# Preview the dataframe to see if it's about right
all_Data
# Out:
# 1 feedlog with a total of 30 flies.
#
# 3 Genotypes [w1118; UAS-ACR1, R58E02-Gal4; w1118, R58E02-Gal4>UAS-GtACR1]
# Categories (3, object): [R58E02-Gal4; w1118 < w1118; UAS-ACR1 < R58E02-Gal4>UAS-GtACR1].
#
# 2 Status types [Sibling, Offspring]
# Categories (2, object): [Sibling < Offspring].
#
# 1 Temperature [Green Light On]
# Categories (1, object): [Green Light On].
#
# 1 FoodChoice [5% sucrose + 5% yeast extract]
# Categories (1, object): [5% sucrose + 5% yeast extract].
#
# 1 Sex type [M]
# Categories (1, object): [M].
#
# 1 type of FlyCountInChamber [1]
# Categories (1, int64): [1].
#
# Total experiment duration = 120 minutes
#
# ESPRESSO v0.7.3

# %%
# Set up a custom palette for plots
CPalette = esp.create_palette(['k', 'gray', 'seagreen'], # green for test, use this for ACR expriments
                                all_Data.feeds.Genotype.cat.categories
                                )

# CPalette = esp.create_palette(['black', 'gray', 'orangered'], # red for test, use this for CsCh expriments
#                                 all_Data.feeds.Genotype.cat.categories
#                                 )

# Preview the custom palette
sns.palplot(CPalette.values())

# %%
# put in the parameters you don't want to type over and over again when using the plot function
groupby='Temperature'
compareby='Status'
colorby='Genotype'
timeToAnalyse=2 #hours




volume1 = all_Data.plot.contrast.feed_volume_per_fly(group_by=groupby, 
                                                       compare_by=compareby,start_hour=0,
                                                    volume_unit="nanoliter",
                                                     end_hour=timeToAnalyse)

fvolume1 = volume1.mean_diff.plot(color_col=colorby,swarm_label="Feed Volume (nl)",
                                custom_palette=CPalette, 
                                    fig_size=(14,5))

fvolume1.savefig(imagepath + 'Volume1' +'deg.png',transparent=True, bbox_inches='tight', dpi=200)
fvolume1.savefig(imagepath + 'Volume1' +'deg.svg',transparent=True, bbox_inches='tight', dpi=200)

# print(imagepath)

count1 = all_Data.plot.contrast.feed_count_per_fly(group_by=groupby, 
                                                       compare_by=compareby,start_hour=0,
                                                     end_hour=timeToAnalyse)

fcount1 = count1.hedges_g.plot(color_col=colorby, fig_size=(18,5))
fcount1.savefig(imagepath + 'Count.png',transparent=True, bbox_inches='tight')
fcount1.savefig(imagepath + 'Count.svg',transparent=True, bbox_inches='tight')



duration = all_Data.plot.contrast.feed_duration_per_fly(group_by=groupby, 
                                                       compare_by=compareby,start_hour=0,
                                                     end_hour=timeToAnalyse)

fduration = duration.hedges_g.plot(color_col=colorby)
fduration.savefig(imagepath + 'Duration.png',transparent=True, bbox_inches='tight')
fduration.savefig(imagepath + 'Duration.svg',transparent=True, bbox_inches='tight')

latency = all_Data.plot.contrast.latency_to_feed(group_by=groupby, 
                                                       compare_by=compareby,start_hour=0,
                                                     end_hour=timeToAnalyse)

flatency = latency.mean_diff.plot(color_col=colorby)
flatency.savefig(imagepath + 'Latency.png',transparent=True, bbox_inches='tight')
flatency.savefig(imagepath + 'Latency.svg',transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Adding Experiments

# %%
a=all_Data.plot.cumulative.consumption(color_by='Status',
                                         col='Sex',
                                         row='Temperature', end_hour=2)




# a.savefig(imagepath + 'CumulativeVolume1' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# a.savefig(imagepath + 'CumulativeVolume1' +'deg.svg',transparent=True, bbox_inches='tight')

# b.savefig(imagepath + 'CumulativeVolume2' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# b.savefig(imagepath + 'CumulativeVolume2' +'deg.svg',transparent=True, bbox_inches='tight')

# c.savefig(imagepath + 'CumulativeVolume3' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# c.savefig(imagepath + 'CumulativeVolume3' +'deg.svg',transparent=True, bbox_inches='tight')

# d.savefig(imagepath + 'CumulativeVolume4' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# d.savefig(imagepath + 'CumulativeVolume4' +'deg.svg',transparent=True, bbox_inches='tight')


# e.savefig(imagepath + 'CumulativeVolume5' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# e.savefig(imagepath + 'CumulativeVolume5' +'deg.svg',transparent=True, bbox_inches='tight')

# f.savefig(imagepath + 'CumulativeVolume6' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# f.savefig(imagepath + 'CumulativeVolume6' +'deg.svg',transparent=True, bbox_inches='tight')

# g.savefig(imagepath + 'CumulativeVolume7' +'deg.png',transparent=True, bbox_inches='tight', dpi=150)
# g.savefig(imagepath + 'CumulativeVolume7' +'deg.svg',transparent=True, bbox_inches='tight')
# Out:
# Munging....
# Plotting....

# %% [markdown]
# ### Cumulative Plots
